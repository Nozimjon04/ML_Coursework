# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %%
df = pd.read_csv("../data/raw/contract_awards_in_investment_project_financing_since_fy_2020_12-04-2025.csv")

df.head()
# Out:
#    As of Date  Fiscal Year                                             Region  \
# 0  12/04/2025         2022                            Europe and Central Asia
# 1  12/04/2025         2022                            Europe and Central Asia
# 2  12/04/2025         2021  Middle East, North Africa, Afghanistan, and Pa...
# 3  12/04/2025         2020                        Eastern and Southern Africa
# 4  12/04/2025         2021                                         South Asia
#
#     Borrower Country / Economy Borrower Country / Economy Code Project ID  \
# 0              Kyrgyz Republic                              KG    P151416
# 1              Kyrgyz Republic                              KG    P151416
# 2                     Pakistan                              PK    P154036
# 3  Eastern and Southern Africa                              3E    P111556
# 4                   Bangladesh                              BD    P149553
#
#                                         Project Name  \
# 0                          Urban Development Project
# 1                          Urban Development Project
# 2  Disaster and Climate Resilience Improvement Pr...
# 3  AFR RI-East Africa Public Health Laboratory Ne...
# 4  Bangladesh NATP-2: National Agricultural Techn...
#
#                              Project Global Practice Procurement Category  \
# 0  Public Admin;Energy & Extractives;Transportati...  Consultant Services
# 1  Public Admin;Energy & Extractives;Transportati...  Consultant Services
# 2      Public Admin;Transportation;Water/Sanit/Waste                Goods
# 3                        Info & Communication;Health                Goods
# 4                                        Agriculture  Consultant Services
#
#                  Procurement Method  WB Contract Number  \
# 0  Quality And Cost-Based Selection             1543858
# 1  Quality And Cost-Based Selection             1543858
# 2            Request for Quotations             1544387
# 3                  Request for Bids             1549740
# 4   Individual Consultant Selection             1553110
#
#                                 Contract Description  \
# 0  Technical Supervision of construction in pilot...
# 1  Technical Supervision of construction in pilot...
# 2  Fixtures and Furnishers for establishment of P...
# 3  SUPPLY OF REAGENTS, SUPPLIES CONSUMABLES AND C...
# 4                      ICT Specialist of PMU, NATP-2
#
#   Borrower Contract Reference Number Contract Signing Date  Supplier ID  \
# 0             UDP PPG-QCBS-2016-4-12            05/19/2022     316882.0
# 1             UDP PPG-QCBS-2016-4-12            05/19/2022     325453.0
# 2         PK-PDMA PUNJAB-2495-GO-RFQ            12/23/2020     330376.0
# 3                TZ-MOH-13063-GO-RFB            06/04/2020     341173.0
# 4                      SD/PMU/IC-07A            11/17/2020          NaN
#
#                   Supplier Supplier Country / Economy  \
# 0    M/S. AIRES INGEGNERIA                      Italy
# 1           ALL INGEGNERIA                      Italy
# 2              FREEZ POINT                   Pakistan
# 3  YUKOS ENTERPRISES (E.A)                   Tanzania
# 4    INDIVIDUAL CONSULTANT                        NaN
#
#   Supplier Country / Economy Code  Supplier Contract Amount (USD) Review type
# 0                              IT                       161538.89       Prior
# 1                              IT                       161538.89       Prior
# 2                              PK                        34059.20        Post
# 3                              TZ                        59575.27        Post
# 4                             NaN                       238123.91        Post

# %%
df.columns
# Out:
# Index(['As of Date', 'Fiscal Year', 'Region', 'Borrower Country / Economy',
#        'Borrower Country / Economy Code', 'Project ID', 'Project Name',
#        'Project Global Practice', 'Procurement Category', 'Procurement Method',
#        'WB Contract Number', 'Contract Description',
#        'Borrower Contract Reference Number', 'Contract Signing Date',
#        'Supplier ID', 'Supplier', 'Supplier Country / Economy',
#        'Supplier Country / Economy Code', 'Supplier Contract Amount (USD)',
#        'Review type'],
#       dtype='object')

# %%
df.shape
# Out:
# (255893, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255893 entries, 0 to 255892
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   As of Date                          255893 non-null  object
#  1   Fiscal Year                         255893 non-null  int64
#  2   Region                              255893 non-null  object
#  3   Borrower Country / Economy          255893 non-null  object
#  4   Borrower Country / Economy Code     247960 non-null  object
#  5   Project ID                          255893 non-null  object
#  6   Project Name                        255893 non-null  object
#  7   Project Global Practice             235420 non-null  object
#  8   Procurement Category                255893 non-null  object
#  9   Procurement Method                  255893 non-null  object
#  10  WB Contract Number                  255893 non-null  int64
#  11  Contract Description                255543 non-null  object
#  12  Borrower Contract Reference Number  255892 non-null  object
#  13  Contract Signing Date               255893 non-null  object
#  14  Supplier ID                         199435 non-null  float64
#  15  Supplier                            255890 non-null  object
#  16  Supplier Country / Economy          199338 non-null  object
#  17  Supplier Country / Economy Code     199428 non-null  object
#  18  Supplier Contract Amount (USD)      255889 non-null  float64
#  19  Review type                         255868 non-null  object
# dtypes: float64(2), int64(2), object(16)
# memory usage: 39.0+ MB

# %%
df.describe(include="all")
# Out:
#         As of Date    Fiscal Year                       Region  \
# count       255893  255893.000000                       255893
# unique           1            NaN                            8
# top     12/04/2025            NaN  Eastern and Southern Africa
# freq        255893            NaN                        56213
# mean           NaN    2022.666654                          NaN
# std            NaN       1.752830                          NaN
# min            NaN    2020.000000                          NaN
# 25%            NaN    2021.000000                          NaN
# 50%            NaN    2023.000000                          NaN
# 75%            NaN    2024.000000                          NaN
# max            NaN    2026.000000                          NaN
#
#        Borrower Country / Economy Borrower Country / Economy Code Project ID  \
# count                      255893                          247960     255893
# unique                        158                             144       2945
# top                         India                              IN    P165129
# freq                        32500                           32500      13719
# mean                          NaN                             NaN        NaN
# std                           NaN                             NaN        NaN
# min                           NaN                             NaN        NaN
# 25%                           NaN                             NaN        NaN
# 50%                           NaN                             NaN        NaN
# 75%                           NaN                             NaN        NaN
# max                           NaN                             NaN        NaN
#
#                                              Project Name  \
# count                                              255893
# unique                                               2934
# top     Integrated Project for Source Sustainability a...
# freq                                                13719
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        Project Global Practice Procurement Category      Procurement Method  \
# count                   235420               255893                  255893
# unique                     239                    4                      18
# top                Agriculture  Consultant Services  Request for Quotations
# freq                     31208                96932                   93141
# mean                       NaN                  NaN                     NaN
# std                        NaN                  NaN                     NaN
# min                        NaN                  NaN                     NaN
# 25%                        NaN                  NaN                     NaN
# 50%                        NaN                  NaN                     NaN
# 75%                        NaN                  NaN                     NaN
# max                        NaN                  NaN                     NaN
#
#         WB Contract Number                               Contract Description  \
# count         2.558930e+05                                             255543
# unique                 NaN                                             221860
# top                    NaN  VACUNADOR (A) DEL DESPLIEGUE PARA LA APLICACIO...
# freq                   NaN                                                354
# mean          1.734033e+06                                                NaN
# std           7.664318e+04                                                NaN
# min           1.543858e+06                                                NaN
# 25%           1.668542e+06                                                NaN
# 50%           1.736469e+06                                                NaN
# 75%           1.800248e+06                                                NaN
# max           1.864613e+06                                                NaN
#
#        Borrower Contract Reference Number Contract Signing Date   Supplier ID  \
# count                              255892                255893  1.994350e+05
# unique                             212217                  2345           NaN
# top                  SB-NSO-412651-NC-RFQ            10/17/2022           NaN
# freq                                  133                   631           NaN
# mean                                  NaN                   NaN  6.548942e+05
# std                                   NaN                   NaN  1.982169e+05
# min                                   NaN                   NaN  0.000000e+00
# 25%                                   NaN                   NaN  5.124905e+05
# 50%                                   NaN                   NaN  6.469780e+05
# 75%                                   NaN                   NaN  8.119365e+05
# max                                   NaN                   NaN  1.041198e+06
#
#                      Supplier Supplier Country / Economy  \
# count                  255890                     199338
# unique                 108550                        224
# top     INDIVIDUAL CONSULTANT                      India
# freq                    56456                      32615
# mean                      NaN                        NaN
# std                       NaN                        NaN
# min                       NaN                        NaN
# 25%                       NaN                        NaN
# 50%                       NaN                        NaN
# 75%                       NaN                        NaN
# max                       NaN                        NaN
#
#        Supplier Country / Economy Code  Supplier Contract Amount (USD)  \
# count                           199428                    2.558890e+05
# unique                             224                             NaN
# top                                 IN                             NaN
# freq                             32615                             NaN
# mean                               NaN                    4.409292e+05
# std                                NaN                    4.698389e+06
# min                                NaN                    0.000000e+00
# 25%                                NaN                    6.956230e+03
# 50%                                NaN                    3.168435e+04
# 75%                                NaN                    1.250989e+05
# max                                NaN                    1.105219e+09
#
#        Review type
# count       255868
# unique           2
# top           Post
# freq        238507
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Supplier Country / Economy            56555
# Supplier Country / Economy Code       56465
# Supplier ID                           56458
# Project Global Practice               20473
# Borrower Country / Economy Code        7933
# Contract Description                    350
# Review type                              25
# Supplier Contract Amount (USD)            4
# Supplier                                  3
# Borrower Contract Reference Number        1
# Fiscal Year                               0
# As of Date                                0
# Borrower Country / Economy                0
# Region                                    0
# WB Contract Number                        0
# Project Name                              0
# Project ID                                0
# Procurement Method                        0
# Procurement Category                      0
# Contract Signing Date                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(634)

# %%
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
categorical_cols = df.select_dtypes(include=['object']).columns.tolist()

numeric_cols, categorical_cols
# Out:
# (['Fiscal Year',
#   'WB Contract Number',
#   'Supplier ID',
#   'Supplier Contract Amount (USD)'],
#  ['As of Date',
#   'Region',
#   'Borrower Country / Economy',
#   'Borrower Country / Economy Code',
#   'Project ID',
#   'Project Name',
#   'Project Global Practice',
#   'Procurement Category',
#   'Procurement Method',
#   'Contract Description',
#   'Borrower Contract Reference Number',
#   'Contract Signing Date',
#   'Supplier',
#   'Supplier Country / Economy',
#   'Supplier Country / Economy Code',
#   'Review type'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
sns.histplot(df[numeric_cols[0]], kde=True)
plt.title(f"Distribution of {numeric_cols[0]}")
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df[numeric_cols].corr(), annot=False, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Supplier Country / Economy            56555
# Supplier Country / Economy Code       56465
# Supplier ID                           56458
# Project Global Practice               20473
# Borrower Country / Economy Code        7933
# Contract Description                    350
# Review type                              25
# Supplier Contract Amount (USD)            4
# Supplier                                  3
# Borrower Contract Reference Number        1
# Fiscal Year                               0
# As of Date                                0
# Borrower Country / Economy                0
# Region                                    0
# WB Contract Number                        0
# Project Name                              0
# Project ID                                0
# Procurement Method                        0
# Procurement Category                      0
# Contract Signing Date                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(634)

# %%
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
categorical_cols = df.select_dtypes(include=['object']).columns.tolist()

numeric_cols, categorical_cols
# Out:
# (['Fiscal Year',
#   'WB Contract Number',
#   'Supplier ID',
#   'Supplier Contract Amount (USD)'],
#  ['As of Date',
#   'Region',
#   'Borrower Country / Economy',
#   'Borrower Country / Economy Code',
#   'Project ID',
#   'Project Name',
#   'Project Global Practice',
#   'Procurement Category',
#   'Procurement Method',
#   'Contract Description',
#   'Borrower Contract Reference Number',
#   'Contract Signing Date',
#   'Supplier',
#   'Supplier Country / Economy',
#   'Supplier Country / Economy Code',
#   'Review type'])

# %%
plt.figure(figsize=(10,6))
sns.histplot(df[numeric_cols[0]], kde=True)
plt.title(f"Distribution of {numeric_cols[0]}")
plt.show()

# %%
#Missing values

df.isnull().sum().sort_values(ascending=False)
# Out:
# Supplier Country / Economy            56555
# Supplier Country / Economy Code       56465
# Supplier ID                           56458
# Project Global Practice               20473
# Borrower Country / Economy Code        7933
# Contract Description                    350
# Review type                              25
# Supplier Contract Amount (USD)            4
# Supplier                                  3
# Borrower Contract Reference Number        1
# Fiscal Year                               0
# As of Date                                0
# Borrower Country / Economy                0
# Region                                    0
# WB Contract Number                        0
# Project Name                              0
# Project ID                                0
# Procurement Method                        0
# Procurement Category                      0
# Contract Signing Date                     0
# dtype: int64

# %%
#Duplicates

df.duplicated().sum()
# Out:
# np.int64(634)

# %%
#Numeric vs categorical

numeric_cols, categorical_cols
# Out:
# (['Fiscal Year',
#   'WB Contract Number',
#   'Supplier ID',
#   'Supplier Contract Amount (USD)'],
#  ['As of Date',
#   'Region',
#   'Borrower Country / Economy',
#   'Borrower Country / Economy Code',
#   'Project ID',
#   'Project Name',
#   'Project Global Practice',
#   'Procurement Category',
#   'Procurement Method',
#   'Contract Description',
#   'Borrower Contract Reference Number',
#   'Contract Signing Date',
#   'Supplier',
#   'Supplier Country / Economy',
#   'Supplier Country / Economy Code',
#   'Review type'])
